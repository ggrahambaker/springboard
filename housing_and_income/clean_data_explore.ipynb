# %%
import requests
import json
import pandas as pd
import numpy as np
from fredapi import Fred

# %% [markdown]
# MINIMUM WAGE

# %%
file = 'minimum_wage_data.csv'
min_wage_df = pd.read_csv(file)
cols = min_wage_df.columns.values
cols[0] = 'year'
min_wage_df.columns = cols
min_wage_df['year'] = pd.to_datetime(min_wage_df['year'])
min_wage_df.set_index('year', inplace=True)
min_wage_df.head()
# Out:
#              AK   AL   AR  AZ    CA    CO    CT   DC    DE  FED ...    SD  \
# year                                                            ...
# 1968-01-01  2.1  1.6  NaN NaN  1.65  1.25  1.40  1.6  1.25  1.6 ...   NaN
# 1969-01-01  2.1  1.6  NaN NaN  1.65  1.25  1.40  1.6  1.25  1.6 ...   NaN
# 1970-01-01  2.1  1.6  1.1 NaN  1.65  1.25  1.60  1.6  1.25  1.6 ...   1.0
# 1971-01-01  2.1  1.6  1.1 NaN  1.65  1.25  1.60  1.6  1.25  1.6 ...   1.0
# 1972-01-01  2.1  1.6  1.2 NaN  1.65  1.25  1.85  1.6  1.60  1.6 ...   1.0
#
#              TN   TX    UT  VA   VT   WA    WI   WV   WY
# year
# 1968-01-01  1.6  NaN  1.15 NaN  1.4  1.6  1.25  1.0  1.2
# 1969-01-01  1.6  NaN  1.15 NaN  1.4  1.6  1.25  1.0  1.2
# 1970-01-01  1.6  NaN  1.15 NaN  1.6  1.6  1.30  1.0  1.3
# 1971-01-01  1.6  NaN  1.15 NaN  1.6  1.6  1.30  1.0  1.3
# 1972-01-01  1.6  1.4  1.35 NaN  1.6  1.6  1.45  1.2  1.5
#
# [5 rows x 52 columns]

# %%
has_null = min_wage_df.columns[min_wage_df.isna().any()].tolist()

for col in has_null:
    #print(col)
    min_wage_df[col].fillna(min_wage_df['FED'], inplace=True)
#min_wage_df.fillna(min_wage_df.FED)
#min_wage_df[has_null].fillna(min_wage_df['FED'], inplace=True)
#min_wage_df[has_null].fillna(min_wage_df['FED'], inplace=True)
min_wage_df.head()
# Out:
#              AK   AL   AR   AZ    CA    CO    CT   DC    DE  FED ...    SD  \
# year                                                             ...
# 1968-01-01  2.1  1.6  1.6  1.6  1.65  1.25  1.40  1.6  1.25  1.6 ...   1.6
# 1969-01-01  2.1  1.6  1.6  1.6  1.65  1.25  1.40  1.6  1.25  1.6 ...   1.6
# 1970-01-01  2.1  1.6  1.1  1.6  1.65  1.25  1.60  1.6  1.25  1.6 ...   1.0
# 1971-01-01  2.1  1.6  1.1  1.6  1.65  1.25  1.60  1.6  1.25  1.6 ...   1.0
# 1972-01-01  2.1  1.6  1.2  1.6  1.65  1.25  1.85  1.6  1.60  1.6 ...   1.0
#
#              TN   TX    UT   VA   VT   WA    WI   WV   WY
# year
# 1968-01-01  1.6  1.6  1.15  1.6  1.4  1.6  1.25  1.0  1.2
# 1969-01-01  1.6  1.6  1.15  1.6  1.4  1.6  1.25  1.0  1.2
# 1970-01-01  1.6  1.6  1.15  1.6  1.6  1.6  1.30  1.0  1.3
# 1971-01-01  1.6  1.6  1.15  1.6  1.6  1.6  1.30  1.0  1.3
# 1972-01-01  1.6  1.4  1.35  1.6  1.6  1.6  1.45  1.2  1.5
#
# [5 rows x 52 columns]

# %% [markdown]
# HOUSING

# %%
file_name_yearly = 'yearly_housing_prices.csv'
housing_df = pd.read_csv(file_name_yearly)
new_columns = housing_df.columns.values
new_columns[0] = 'year'
#housing_df
housing_df.columns = new_columns

housing_df['year'] = pd.to_datetime(housing_df['year'], format="%Y")

housing_df.head()
housing_df.reset_index()
housing_df.set_index('year')
# Out:
#                     AK          AL          AR          AZ          CA  \
# year
# 1975-01-01   37.471667   36.267500   38.076667   29.530833   16.757500
# 1976-01-01   41.563333   38.497500   40.632500   30.220000   19.393333
# 1977-01-01   44.965000   40.751667   44.240000   32.535833   24.271667
# 1978-01-01   49.288333   44.843333   48.285833   37.719167   28.767500
# 1979-01-01   55.193333   49.214167   53.958333   46.006667   33.729167
# 1980-01-01   55.758333   51.750833   57.023333   52.133333   38.613333
# 1981-01-01   64.613333   52.526667   59.683333   55.506667   42.108333
# 1982-01-01   75.913333   53.295000   58.595000   56.498333   42.840833
# 1983-01-01   83.536667   55.337500   64.036667   58.965833   43.399167
# 1984-01-01   85.624167   58.350833   64.683333   60.808333   44.559167
# 1985-01-01   82.330833   60.033333   66.526667   61.899167   46.569167
# 1986-01-01   79.063333   63.154167   68.298333   64.378333   49.515000
# ...
